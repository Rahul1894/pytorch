# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # generator wants to generate such image so that the probability distribution of generated image is much similar to probability distribution of real image that's why generator wants to put those closer to each other (minimize) and discriminator wants to separate them as much as possible (maximize)
